# %% [markdown]
# # Fossil Fuel Jobs in CA: Data Exploration
#
# ### Author: Rachel Lu
#
# ### Description
#
# This project visualizes fossil fuel job employment data in California. My data are from the County Business Patterns (CBP)  2018 Survey produced by the United States Census Bureau and the CA County Boundraries dataset from US Census Bureau's 2016 MAF/TIGER database. The former provides countywide employment by fossil fuel industry and the latter provides county geometry data.

# %% [markdown]
# ## Importing Libraries
# First, we import the modules we'll need to work with and visualize our data.

# %%
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %% [markdown]
# We've now given ourselves the ability to work with data generally (pandas module), read and visualize spatial data (geopandas module), provide basemaps (contextily), and produce more robust and interesting plots (matplotlib.pyplot module).

# %% [markdown]
# ## Importing & Inspecting Data: FFJOBS
#
# Next, we import our fossil fuel jobs data and give it a label. We're going with the name ffjobs.

# %%
ffjobs = gpd.read_file('CBP2018.CB1800CBP_2021-01-23T142924_Extended_Filtered.csv')

# %% [markdown]
# Now, let's take a look at the data we've imported.

# %%
ffjobs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GEO_ID           109 non-null    object
#  1   NAME             109 non-null    object
#  2   NAICS2017        109 non-null    object
#  3   NAICS2017_LABEL  109 non-null    object
#  4   NAICS2017_F      109 non-null    object
#  5   LFO              109 non-null    object
#  6   LFO_LABEL        109 non-null    object
#  7   EMPSZES          109 non-null    object
#  8   EMPSZES_LABEL    109 non-null    object
#  9   YEAR             109 non-null    object
#  10  ESTAB            109 non-null    object
#  11  PAYANN           109 non-null    object
#  12  PAYANN_N         109 non-null    object
#  13  PAYQTR1          109 non-null    object
#  14  PAYQTR1_N        109 non-null    object
#  15  EMP              109 non-null    object
#  16  EMP_N            109 non-null    object
#  17  geometry         0 non-null      geometry
# dtypes: geometry(1), object(17)
# memory usage: 15.5+ KB

# %% [markdown]
# I output a list of all the columns, counts, and associated data types. Usually I skim through this section quickly, but there is a tiny, very significant detail here that causes hours of frustration down the road: our dataset has 0 non-null geometry values! That is not good. Without it, I can't map the data, which is kind of the entire point of this exercise.

# %% [markdown]
# I want to see what the values look like for each column. Overall, I just want a closer look at what's going on with the data.

# %%
ffjobs.head(5)
# Out:
#            GEO_ID                             NAME NAICS2017  \
# 0  0500000US06013  Contra Costa County, California      2111
# 1  0500000US06013  Contra Costa County, California      2111
# 2  0500000US06013  Contra Costa County, California     32411
# 3  0500000US06013  Contra Costa County, California       486
# 4  0500000US06013  Contra Costa County, California       486
#
#            NAICS2017_LABEL NAICS2017_F LFO           LFO_LABEL EMPSZES  \
# 0   Oil and gas extraction        null   1  All establishments       1
# 1   Oil and gas extraction        null   1  All establishments     210
# 2     Petroleum refineries        null   1  All establishments       1
# 3  Pipeline transportation        null   1  All establishments       1
# 4  Pipeline transportation        null   1  All establishments     241
#
#                                EMPSZES_LABEL  YEAR ESTAB  PAYANN PAYANN_N  \
# 0                         All establishments  2018     8    2774        H
# 1  Establishments with less than 5 employees  2018     7       N        N
# 2                         All establishments  2018     5  434252        G
# 3                         All establishments  2018     6   10176        H
# 4     Establishments with 20 to 49 employees  2018     3       N        N
#
#   PAYQTR1 PAYQTR1_N   EMP EMP_N geometry
# 0     397         G    34     J     None
# 1       N         N     N     N     None
# 2  116506         G  3357     G     None
# 3    2969         H    91     J     None
# 4       N         N     N     N     None

# %% [markdown]
# I create a dataframe that outputs the first five rows of the dataset. Scrolling all the way over to the right, I confirm that there are no values in the geometry column. Next up: a lot of troubleshooting.

# %% [markdown]
# ## Importing & Inspecting Data: CA Counties
#
# I know that our ffjobs dataset contains employment data at the county level, which means that I'll need to add county geometry data to our dataset. I seek out another dataset that has geometry data for CA county boundaries and quickly find a CA County Boundaries shapefil via the CA Open Data Portal. Bless the CA Open Data Portal.
#
# Our next step is to upload this dataset into Jupyterhub. I creatively name it counties.

# %%
counties = gpd.read_file('CA_Counties_TIGER2016.shp')

# %% [markdown]
# This uploads the counties dataset. Now I can use this dataset for the basemap in addition to replacing the missing data from ffjobs.

# %% [markdown]
# Okay, next, let's explore the counties dataset and learn more about the data we're working with.

# %%
counties.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   58 non-null     object
#  1   COUNTYFP  58 non-null     object
#  2   COUNTYNS  58 non-null     object
#  3   GEOID     58 non-null     object
#  4   NAME      58 non-null     object
#  5   NAMELSAD  58 non-null     object
#  6   LSAD      58 non-null     object
#  7   CLASSFP   58 non-null     object
#  8   MTFCC     58 non-null     object
#  9   CSAFP     32 non-null     object
#  10  CBSAFP    45 non-null     object
#  11  METDIVFP  7 non-null      object
#  12  FUNCSTAT  58 non-null     object
#  13  ALAND     58 non-null     int64
#  14  AWATER    58 non-null     int64
#  15  INTPTLAT  58 non-null     object
#  16  INTPTLON  58 non-null     object
#  17  geometry  58 non-null     geometry
# dtypes: geometry(1), int64(2), object(15)
# memory usage: 8.3+ KB

# %% [markdown]
# This produces a table that tells us the column names, non-null counts, and data types we're working with. And this time we have geometry data! Progress.

# %% [markdown]
# After the hours wasted trying to plot the ffjobs dataset without geometry data, I'm extra careful and want to make sure the counties dataset plots well. So, let's double check early on by using the plot function.

# %%
counties.plot()

# %% [markdown]
# We produce plot of all the counties in California. It's working as expected. The map is a terrible shade of blue, which we'll fix later.

# %% [markdown]
# Next, I want to take a deeper look at the data contained within the counties dataset.

# %%
counties.head(10)
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 3      06      009  01675885  06009      Calaveras      Calaveras County   06
# 4      06      111  00277320  06111        Ventura        Ventura County   06
# 5      06      037  00277283  06037    Los Angeles    Los Angeles County   06
# 6      06      097  01657246  06097         Sonoma         Sonoma County   06
# 7      06      031  00277280  06031          Kings          Kings County   06
# 8      06      073  00277301  06073      San Diego      San Diego County   06
# 9      06      061  00277295  06061         Placer         Placer County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT        ALAND      AWATER  \
# 0      H1  G4020  None   None     None        A   2468694587    23299110
# 1      H1  G4020   472  40900     None        A   2499183617    76073827
# 2      H1  G4020  None  42200     None        A   7084000598  2729814515
# 3      H1  G4020  None   None     None        A   2641820834    43806026
# 4      H1  G4020   348  37100     None        A   4773390489   945942791
# 5      H1  G4020   348  31080    31084        A  10510651024  1794730436
# 6      H1  G4020   488  42220     None        A   4081437574   497508807
# 7      H1  G4020   546  25260     None        A   3598583450     5468555
# 8      H1  G4020  None  41740     None        A  10895149811   826195031
# 9      H1  G4020   472  40900     None        A   3644333049   246486852
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# 1  +38.4500114  -121.3404409
# 2  +34.5370572  -120.0399729
# 3  +38.1838996  -120.5614415
# 4  +34.3587415  -119.1331432
# 5  +34.1963983  -118.2618616
# 6  +38.5251824  -122.9261095
# 7  +36.0724780  -119.8155301
# 8  +33.0236041  -116.7761174
# 9  +39.0620323  -120.7227181
#
#                                             geometry
# 0  POLYGON ((-13431319.751 4821511.426, -13431312...
# 1  POLYGON ((-13490651.476 4680831.603, -13490511...
# 2  MULTIPOLYGON (((-13423116.772 4042044.149, -13...
# 3  POLYGON ((-13428575.483 4627725.228, -13428534...
# 4  MULTIPOLYGON (((-13317853.594 3931602.414, -13...
# 5  MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 6  POLYGON ((-13685069.767 4623872.832, -13685073...
# 7  POLYGON ((-13353767.857 4335831.239, -13353767...
# 8  POLYGON ((-13073075.796 3919158.524, -13074423...
# 9  POLYGON ((-13476944.153 4722608.150, -13476936...

# %% [markdown]
# I output a dataframe the includes the first 10 rows of the dataset. Note that there's both polygon and multipolygon data in the geometry field. I'm happy to see a GEOID but am confused as to why it doesn't match up with the GEO_ID field from the ffjobs dataset. More complications!

# %% [markdown]
# ## Figuring Out How to Match the Data
#
# Because the jobs dataset does not contain values for the geometry field, I have to splice geometry data from the counties dataset into the corresponding county row in the ffjobs dataset. We'll need a way to identify the right counties to splice the geometry data into. The counties dataset and ffjobs dataset have ID fields that could be matched: GEO_ID (ffjobs) with GEOID (counties). Let's start the process to figure out how we can match the counties in the ffjobs dataset with their corresponding geometry data from the counties dataset.

# %% [markdown]
# First, I want to compare the GEO_ID field to the GEOID field. I want to find out which counties exist in the ffjobs dataset in order to compare the values in GEO_ID with GEOID.

# %%
ffjobs['NAME'].value_counts()
# Out:
# Los Angeles County, California        22
# Kern County, California               14
# San Diego County, California          13
# Orange County, California             10
# San Bernardino County, California      8
# Contra Costa County, California        7
# Santa Barbara County, California       7
# Sacramento County, California          5
# Riverside County, California           5
# Ventura County, California             4
# Fresno County, California              3
# San Joaquin County, California         2
# Santa Clara County, California         2
# Sutter County, California              2
# Tulare County, California              1
# San Luis Obispo County, California     1
# Solano County, California              1
# Alameda County, California             1
# Monterey County, California            1
# Name: NAME, dtype: int64

# %% [markdown]
# I produce a list of all the unique county names in the ffjobs dataset, plus the number of times that value occurs.
#
# I remember that Los Angeles County appears in the first 10 rows of the counties dataframe produced above. So, I choose to check out what the ffjobs GEO_ID data looks like for Los Angeles County in order to compare it to the values in the GEOID counties data.

# %%
ffjobs[ffjobs.NAME == 'Los Angeles County, California']
# Out:
#             GEO_ID                            NAME NAICS2017  \
# 19  0500000US06037  Los Angeles County, California      2111
# 20  0500000US06037  Los Angeles County, California      2111
# 21  0500000US06037  Los Angeles County, California      2111
# 22  0500000US06037  Los Angeles County, California      2111
# 23  0500000US06037  Los Angeles County, California      2111
# 24  0500000US06037  Los Angeles County, California      2212
# 25  0500000US06037  Los Angeles County, California      2212
# 26  0500000US06037  Los Angeles County, California      2212
# 27  0500000US06037  Los Angeles County, California      2212
# 28  0500000US06037  Los Angeles County, California      2212
# 29  0500000US06037  Los Angeles County, California      2212
# 30  0500000US06037  Los Angeles County, California      2212
# 31  0500000US06037  Los Angeles County, California     32411
# 32  0500000US06037  Los Angeles County, California       486
# 33  0500000US06037  Los Angeles County, California       486
# 34  0500000US06037  Los Angeles County, California       486
# 35  0500000US06037  Los Angeles County, California       486
# 36  0500000US06037  Los Angeles County, California       486
# 91  0500000US06037  Los Angeles County, California    221112
# 92  0500000US06037  Los Angeles County, California    221112
# 93  0500000US06037  Los Angeles County, California    221112
# 94  0500000US06037  Los Angeles County, California    221112
#
#                           NAICS2017_LABEL NAICS2017_F LFO           LFO_LABEL  \
# 19                 Oil and gas extraction        null   1  All establishments
# 20                 Oil and gas extraction        null   1  All establishments
# 21                 Oil and gas extraction        null   1  All establishments
# 22                 Oil and gas extraction        null   1  All establishments
# 23                 Oil and gas extraction        null   1  All establishments
# 24               Natural gas distribution        null   1  All establishments
# 25               Natural gas distribution        null   1  All establishments
# 26               Natural gas distribution        null   1  All establishments
# 27               Natural gas distribution        null   1  All establishments
# 28               Natural gas distribution        null   1  All establishments
# 29               Natural gas distribution        null   1  All establishments
# 30               Natural gas distribution        null   1  All establishments
# 31                   Petroleum refineries        null   1  All establishments
# 32                Pipeline transportation        null   1  All establishments
# 33                Pipeline transportation        null   1  All establishments
# 34                Pipeline transportation        null   1  All establishments
# 35                Pipeline transportation        null   1  All establishments
# 36                Pipeline transportation        null   1  All establishments
# 91  Fossil fuel electric power generation        null   1  All establishments
# 92  Fossil fuel electric power generation        null   1  All establishments
# 93  Fossil fuel electric power generation        null   1  All establishments
# 94  Fossil fuel electric power generation        null   1  All establishments
#
#    EMPSZES                              EMPSZES_LABEL  YEAR ESTAB  PAYANN  \
# 19       1                         All establishments  2018    39  235735
# 20     210  Establishments with less than 5 employees  2018    20       N
# 21     220       Establishments with 5 to 9 employees  2018     9       N
# 22     230     Establishments with 10 to 19 employees  2018     3       N
# 23     242     Establishments with 50 to 99 employees  2018     4       N
# 24       1                         All establishments  2018    61  507130
# 25     210  Establishments with less than 5 employees  2018    21       N
# 26     230     Establishments with 10 to 19 employees  2018     4       N
# 27     241     Establishments with 20 to 49 employees  2018     5       N
# 28     242     Establishments with 50 to 99 employees  2018    18       N
# 29     251   Establishments with 100 to 249 employees  2018     5       N
# 30     252   Establishments with 250 to 499 employees  2018     5       N
# 31       1                         All establishments  2018     8  606915
# 32       1                         All establishments  2018    19   52243
# 33     210  Establishments with less than 5 employees  2018     7       N
# 34     220       Establishments with 5 to 9 employees  2018     3       N
# 35     241     Establishments with 20 to 49 employees  2018     3       N
# 36     242     Establishments with 50 to 99 employees  2018     3       N
# 91       1                         All establishments  2018    14   48523
# 92     210  Establishments with less than 5 employees  2018     3       N
# 93     220       Establishments with 5 to 9 employees  2018     4       N
# 94     241     Establishments with 20 to 49 employees  2018     4       N
#
#    PAYANN_N PAYQTR1 PAYQTR1_N   EMP EMP_N geometry
# 19        J   65894         J  1446     J     None
# 20        N       N         N     N     N     None
# 21        N       N         N     N     N     None
# 22        N       N         N     N     N     None
# 23        N       N         N     N     N     None
# 24        J  177315         J  5074     J     None
# 25        N       N         N     N     N     None
# 26        N       N         N     N     N     None
# 27        N       N         N     N     N     None
# 28        N       N         N     N     N     None
# 29        N       N         N     N     N     None
# 30        N       N         N     N     N     None
# 31        H  196982         H  4425     H     None
# 32        H   16882         H   436     H     None
# 33        N       N         N     N     N     None
# 34        N       N         N     N     N     None
# 35        N       N         N     N     N     None
# 36        N       N         N     N     N     None
# 91        G   16788         H   329     G     None
# 92        N       N         N     N     N     None
# 93        N       N         N     N     N     None
# 94        N       N         N     N     N     None

# %% [markdown]
# I produce a dataframe that includes all the rows where NAME = Los Angeles County, CA. I notice that the last 5 digits of GEO_ID (ffjobs) for Los Angeles County correspond to the GEOID (counties) values for Los Angeles County. Maybe we can use this to add the geometry data from the counties dataset to the right counties in ffjobs dataset.

# %% [markdown]
# ## Cleaning and Trimming the Data (Assignment 4 Update)
#
#
# Now it's time to clean and trim the data. There are a lot of columns that we don't need, and a few "N" values, meaning not applicable, in the EMP column. We also want to rename columns so that they're more intuitive.

# %%
desired_columns = ['GEO_ID','NAME','NAICS2017_LABEL','EMP','geometry']
ffjobs[desired_columns]
# Out:
#              GEO_ID                             NAME  \
# 0    0500000US06013  Contra Costa County, California
# 1    0500000US06013  Contra Costa County, California
# 2    0500000US06013  Contra Costa County, California
# 3    0500000US06013  Contra Costa County, California
# 4    0500000US06013  Contra Costa County, California
# ..              ...                              ...
# 104  0500000US06073     San Diego County, California
# 105  0500000US06085   Santa Clara County, California
# 106  0500000US06085   Santa Clara County, California
# 107  0500000US06101        Sutter County, California
# 108  0500000US06101        Sutter County, California
#
#                            NAICS2017_LABEL   EMP geometry
# 0                   Oil and gas extraction    34     None
# 1                   Oil and gas extraction     N     None
# 2                     Petroleum refineries  3357     None
# 3                  Pipeline transportation    91     None
# 4                  Pipeline transportation     N     None
# ..                                     ...   ...      ...
# 104  Fossil fuel electric power generation     N     None
# 105  Fossil fuel electric power generation    70     None
# 106  Fossil fuel electric power generation     N     None
# 107  Fossil fuel electric power generation    13     None
# 108  Fossil fuel electric power generation     N     None
#
# [109 rows x 5 columns]

# %% [markdown]
# Now let's redefine our dataframe with just our desired columns.

# %%
ffjobs_trimmed = ffjobs[desired_columns].copy()
ffjobs_trimmed
# Out:
#              GEO_ID                             NAME  \
# 0    0500000US06013  Contra Costa County, California
# 1    0500000US06013  Contra Costa County, California
# 2    0500000US06013  Contra Costa County, California
# 3    0500000US06013  Contra Costa County, California
# 4    0500000US06013  Contra Costa County, California
# ..              ...                              ...
# 104  0500000US06073     San Diego County, California
# 105  0500000US06085   Santa Clara County, California
# 106  0500000US06085   Santa Clara County, California
# 107  0500000US06101        Sutter County, California
# 108  0500000US06101        Sutter County, California
#
#                            NAICS2017_LABEL   EMP geometry
# 0                   Oil and gas extraction    34     None
# 1                   Oil and gas extraction     N     None
# 2                     Petroleum refineries  3357     None
# 3                  Pipeline transportation    91     None
# 4                  Pipeline transportation     N     None
# ..                                     ...   ...      ...
# 104  Fossil fuel electric power generation     N     None
# 105  Fossil fuel electric power generation    70     None
# 106  Fossil fuel electric power generation     N     None
# 107  Fossil fuel electric power generation    13     None
# 108  Fossil fuel electric power generation     N     None
#
# [109 rows x 5 columns]

# %% [markdown]
# Yep, it's redefined!

# %% [markdown]
# Now I want to rename the columns so they're more intuitive. First, I generate a list of current columns.

# %%
list(ffjobs_trimmed)
# Out:
# ['GEO_ID', 'NAME', 'NAICS2017_LABEL', 'EMP', 'geometry']

# %% [markdown]
# Then I copy and paste the output list above and define the columns with it. Then I replace the values with desired column names

# %%
ffjobs_trimmed.columns = ['GEO_ID', 'NAME', 'JOBTYPE_NAICS', 'EMPLOYMENT', 'geometry']

# %% [markdown]
# Let's double check to see that they were properly renamed.

# %%
ffjobs_trimmed
# Out:
#              GEO_ID                             NAME  \
# 0    0500000US06013  Contra Costa County, California
# 1    0500000US06013  Contra Costa County, California
# 2    0500000US06013  Contra Costa County, California
# 3    0500000US06013  Contra Costa County, California
# 4    0500000US06013  Contra Costa County, California
# ..              ...                              ...
# 104  0500000US06073     San Diego County, California
# 105  0500000US06085   Santa Clara County, California
# 106  0500000US06085   Santa Clara County, California
# 107  0500000US06101        Sutter County, California
# 108  0500000US06101        Sutter County, California
#
#                              JOBTYPE_NAICS EMPLOYMENT geometry
# 0                   Oil and gas extraction         34     None
# 1                   Oil and gas extraction          N     None
# 2                     Petroleum refineries       3357     None
# 3                  Pipeline transportation         91     None
# 4                  Pipeline transportation          N     None
# ..                                     ...        ...      ...
# 104  Fossil fuel electric power generation          N     None
# 105  Fossil fuel electric power generation         70     None
# 106  Fossil fuel electric power generation          N     None
# 107  Fossil fuel electric power generation         13     None
# 108  Fossil fuel electric power generation          N     None
#
# [109 rows x 5 columns]

# %% [markdown]
# Now let's drop all rows with N for employment.

# %%
ffjobs_trimmed2 = ffjobs_trimmed[ffjobs_trimmed.EMPLOYMENT != 'N']
ffjobs_trimmed2
# Out:
#              GEO_ID                                NAME  \
# 0    0500000US06013     Contra Costa County, California
# 2    0500000US06013     Contra Costa County, California
# 3    0500000US06013     Contra Costa County, California
# 5    0500000US06019           Fresno County, California
# 6    0500000US06029             Kern County, California
# 13   0500000US06029             Kern County, California
# 14   0500000US06029             Kern County, California
# 15   0500000US06029             Kern County, California
# 19   0500000US06037      Los Angeles County, California
# 24   0500000US06037      Los Angeles County, California
# 31   0500000US06037      Los Angeles County, California
# 32   0500000US06037      Los Angeles County, California
# 37   0500000US06053         Monterey County, California
# 38   0500000US06059           Orange County, California
# 41   0500000US06059           Orange County, California
# 45   0500000US06059           Orange County, California
# 46   0500000US06065        Riverside County, California
# 50   0500000US06065        Riverside County, California
# 51   0500000US06067       Sacramento County, California
# 53   0500000US06067       Sacramento County, California
# 54   0500000US06071   San Bernardino County, California
# 58   0500000US06071   San Bernardino County, California
# 60   0500000US06073        San Diego County, California
# 62   0500000US06073        San Diego County, California
# 69   0500000US06077      San Joaquin County, California
# 71   0500000US06079  San Luis Obispo County, California
# 72   0500000US06083    Santa Barbara County, California
# 76   0500000US06083    Santa Barbara County, California
# 78   0500000US06083    Santa Barbara County, California
# 79   0500000US06095           Solano County, California
# 80   0500000US06107           Tulare County, California
# 81   0500000US06111          Ventura County, California
# 83   0500000US06111          Ventura County, California
# 85   0500000US06001          Alameda County, California
# 86   0500000US06013     Contra Costa County, California
# 88   0500000US06019           Fresno County, California
# 90   0500000US06029             Kern County, California
# 91   0500000US06037      Los Angeles County, California
# 95   0500000US06059           Orange County, California
# 97   0500000US06067       Sacramento County, California
# 99   0500000US06071   San Bernardino County, California
# 101  0500000US06073        San Diego County, California
# 105  0500000US06085      Santa Clara County, California
# 107  0500000US06101           Sutter County, California
#
#                              JOBTYPE_NAICS EMPLOYMENT geometry
# 0                   Oil and gas extraction         34     None
# 2                     Petroleum refineries       3357     None
# 3                  Pipeline transportation         91     None
# 5                  Pipeline transportation         34     None
# 6                   Oil and gas extraction       2246     None
# 13                Natural gas distribution        106     None
# 14                    Petroleum refineries        295     None
# 15                 Pipeline transportation        392     None
# 19                  Oil and gas extraction       1446     None
# 24                Natural gas distribution       5074     None
# 31                    Petroleum refineries       4425     None
# 32                 Pipeline transportation        436     None
# 37                  Oil and gas extraction         37     None
# 38                  Oil and gas extraction         64     None
# 41                Natural gas distribution        766     None
# 45                 Pipeline transportation        141     None
# 46                Natural gas distribution        427     None
# 50                 Pipeline transportation          7     None
# 51                Natural gas distribution         34     None
# 53                 Pipeline transportation         17     None
# 54                Natural gas distribution       1026     None
# 58                 Pipeline transportation         59     None
# 60                  Oil and gas extraction         14     None
# 62                Natural gas distribution       1873     None
# 69                 Pipeline transportation         18     None
# 71                Natural gas distribution         85     None
# 72                  Oil and gas extraction        193     None
# 76                Natural gas distribution        136     None
# 78                 Pipeline transportation         16     None
# 79                 Pipeline transportation         26     None
# 80                Natural gas distribution        119     None
# 81                  Oil and gas extraction        284     None
# 83                Natural gas distribution        172     None
# 85   Fossil fuel electric power generation         71     None
# 86   Fossil fuel electric power generation        107     None
# 88   Fossil fuel electric power generation         22     None
# 90   Fossil fuel electric power generation        143     None
# 91   Fossil fuel electric power generation        329     None
# 95   Fossil fuel electric power generation         41     None
# 97   Fossil fuel electric power generation         74     None
# 99   Fossil fuel electric power generation         66     None
# 101  Fossil fuel electric power generation        492     None
# 105  Fossil fuel electric power generation         70     None
# 107  Fossil fuel electric power generation         13     None

# %% [markdown]
# We've now created a new dataframe that removed all rows where employment = N.

# %% [markdown]
# Now, let's make sure employment is in integers.

# %%
print(ffjobs_trimmed2.dtypes)
# Out:
# GEO_ID             object
# NAME               object
# JOBTYPE_NAICS      object
# EMPLOYMENT          int64
# geometry         geometry
# dtype: object

# %% [markdown]
# We print a list of datatypes for each of the columns in our dataframe. Great, employment is in integers!

# %% [markdown]
# ## Setting geometry in ffjobs equal to geometry from counties dataset
#
# I want to set the geometry values in ffjobs equal to the corresponding geometry values from the counties dataset. However, I first need to be able to match the fields correctly. We can see that the values in the GEOID column from the counties dataset correspond to the last five digits of the GEO_ID column from the ffjobs dataset.
#
# First, I have to isolate the last 5 digits of the GEO_ID field. Then, I have to match it with the corresponding GEOID in the county dataset. Finally, I set the geometry field in the ffjobs dataset equal to the corresponding geometry data in the county dataset.
#
# I create a for loop that helps me do the above for each row in the ffjobs dataset.

# %%
# create a for loop to iterate through each row and run the following code. 
for index, row in ffjobs_trimmed2.iterrows():
    
    # create a new variable 'geomid' to store the value of GEO_ID for a row 
    geomid = row['GEO_ID']
    
    # isolate the last 5 digits of the GEO_ID column from the ffjobs dataset. 
    last_digits = geomid[-5:]
    
    # create a new variable 'countyrow' that finds the collection of rows in county dataset where 
    # GEOID is equal to the last 5 digits in the ffjobs dataset. In other words, we are creating a 
    # dataframe containing the single row in the counties dataset that corresponds to last_digits 
    countyrow = counties[counties.GEOID == last_digits]

    # Set the geometry field in this ffjobs row equal to the geometry data we pulled from the counties dataframe. 
    # Workaround because of a geopandas bug that prevents me from inserting multipolygon data into the geometry column.
    # Issue here: https://github.com/geopandas/geopandas/issues/992
    ffjobs_trimmed2.loc[[index], 'geometry'] = countyrow['geometry'].values
# Out:
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/conda/lib/python3.8/site-packages/geopandas/geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
ffjobs_trimmed2
# Out:
#              GEO_ID                                NAME  \
# 0    0500000US06013     Contra Costa County, California
# 2    0500000US06013     Contra Costa County, California
# 3    0500000US06013     Contra Costa County, California
# 5    0500000US06019           Fresno County, California
# 6    0500000US06029             Kern County, California
# 13   0500000US06029             Kern County, California
# 14   0500000US06029             Kern County, California
# 15   0500000US06029             Kern County, California
# 19   0500000US06037      Los Angeles County, California
# 24   0500000US06037      Los Angeles County, California
# 31   0500000US06037      Los Angeles County, California
# 32   0500000US06037      Los Angeles County, California
# 37   0500000US06053         Monterey County, California
# 38   0500000US06059           Orange County, California
# 41   0500000US06059           Orange County, California
# 45   0500000US06059           Orange County, California
# 46   0500000US06065        Riverside County, California
# 50   0500000US06065        Riverside County, California
# 51   0500000US06067       Sacramento County, California
# 53   0500000US06067       Sacramento County, California
# 54   0500000US06071   San Bernardino County, California
# 58   0500000US06071   San Bernardino County, California
# 60   0500000US06073        San Diego County, California
# 62   0500000US06073        San Diego County, California
# 69   0500000US06077      San Joaquin County, California
# 71   0500000US06079  San Luis Obispo County, California
# 72   0500000US06083    Santa Barbara County, California
# 76   0500000US06083    Santa Barbara County, California
# 78   0500000US06083    Santa Barbara County, California
# 79   0500000US06095           Solano County, California
# 80   0500000US06107           Tulare County, California
# 81   0500000US06111          Ventura County, California
# 83   0500000US06111          Ventura County, California
# 85   0500000US06001          Alameda County, California
# 86   0500000US06013     Contra Costa County, California
# 88   0500000US06019           Fresno County, California
# 90   0500000US06029             Kern County, California
# 91   0500000US06037      Los Angeles County, California
# 95   0500000US06059           Orange County, California
# 97   0500000US06067       Sacramento County, California
# 99   0500000US06071   San Bernardino County, California
# 101  0500000US06073        San Diego County, California
# 105  0500000US06085      Santa Clara County, California
# 107  0500000US06101           Sutter County, California
#
#                              JOBTYPE_NAICS  EMPLOYMENT  \
# 0                   Oil and gas extraction          34
# 2                     Petroleum refineries        3357
# 3                  Pipeline transportation          91
# 5                  Pipeline transportation          34
# 6                   Oil and gas extraction        2246
# 13                Natural gas distribution         106
# 14                    Petroleum refineries         295
# 15                 Pipeline transportation         392
# 19                  Oil and gas extraction        1446
# 24                Natural gas distribution        5074
# 31                    Petroleum refineries        4425
# 32                 Pipeline transportation         436
# 37                  Oil and gas extraction          37
# 38                  Oil and gas extraction          64
# 41                Natural gas distribution         766
# 45                 Pipeline transportation         141
# 46                Natural gas distribution         427
# 50                 Pipeline transportation           7
# 51                Natural gas distribution          34
# 53                 Pipeline transportation          17
# 54                Natural gas distribution        1026
# 58                 Pipeline transportation          59
# 60                  Oil and gas extraction          14
# 62                Natural gas distribution        1873
# 69                 Pipeline transportation          18
# 71                Natural gas distribution          85
# 72                  Oil and gas extraction         193
# 76                Natural gas distribution         136
# 78                 Pipeline transportation          16
# 79                 Pipeline transportation          26
# 80                Natural gas distribution         119
# 81                  Oil and gas extraction         284
# 83                Natural gas distribution         172
# 85   Fossil fuel electric power generation          71
# 86   Fossil fuel electric power generation         107
# 88   Fossil fuel electric power generation          22
# 90   Fossil fuel electric power generation         143
# 91   Fossil fuel electric power generation         329
# 95   Fossil fuel electric power generation          41
# 97   Fossil fuel electric power generation          74
# 99   Fossil fuel electric power generation          66
# 101  Fossil fuel electric power generation         492
# 105  Fossil fuel electric power generation          70
# 107  Fossil fuel electric power generation          13
#
#                                               geometry
# 0    POLYGON ((-13610773.230 4565908.502, -13610791...
# 2    POLYGON ((-13610773.230 4565908.502, -13610791...
# 3    POLYGON ((-13610773.230 4565908.502, -13610791...
# 5    POLYGON ((-13325540.690 4439078.780, -13325502...
# 6    POLYGON ((-13348728.860 4223737.154, -13349798...
# 13   POLYGON ((-13348728.860 4223737.154, -13349798...
# 14   POLYGON ((-13348728.860 4223737.154, -13349798...
# 15   POLYGON ((-13348728.860 4223737.154, -13349798...
# 19   MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 24   MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 31   MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 32   MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 37   POLYGON ((-13583963.802 4376069.357, -13583986...
# 38   POLYGON ((-13134488.102 3973319.471, -13134662...
# 41   POLYGON ((-13134488.102 3973319.471, -13134662...
# 45   POLYGON ((-13134488.102 3973319.471, -13134662...
# 46   POLYGON ((-13099281.751 4011348.117, -13099285...
# 50   POLYGON ((-13099281.751 4011348.117, -13099285...
# 51   POLYGON ((-13490651.476 4680831.603, -13490511...
# 53   POLYGON ((-13490651.476 4680831.603, -13490511...
# 54   POLYGON ((-13098659.037 4127837.220, -13098658...
# 58   POLYGON ((-13098659.037 4127837.220, -13098658...
# 60   POLYGON ((-13073075.796 3919158.524, -13074423...
# 62   POLYGON ((-13073075.796 3919158.524, -13074423...
# 69   POLYGON ((-13492801.940 4614635.904, -13492706...
# 71   POLYGON ((-13490260.152 4272335.748, -13490212...
# 72   MULTIPOLYGON (((-13423116.772 4042044.149, -13...
# 76   MULTIPOLYGON (((-13423116.772 4042044.149, -13...
# 78   MULTIPOLYGON (((-13423116.772 4042044.149, -13...
# 79   POLYGON ((-13588190.514 4624150.922, -13588223...
# 80   POLYGON ((-13225172.001 4271812.344, -13225308...
# 81   MULTIPOLYGON (((-13317853.594 3931602.414, -13...
# 83   MULTIPOLYGON (((-13317853.594 3931602.414, -13...
# 85   POLYGON ((-13612246.763 4538150.085, -13612346...
# 86   POLYGON ((-13610773.230 4565908.502, -13610791...
# 88   POLYGON ((-13325540.690 4439078.780, -13325502...
# 90   POLYGON ((-13348728.860 4223737.154, -13349798...
# 91   MULTIPOLYGON (((-13210018.388 3958856.141, -13...
# 95   POLYGON ((-13134488.102 3973319.471, -13134662...
# 97   POLYGON ((-13490651.476 4680831.603, -13490511...
# 99   POLYGON ((-13098659.037 4127837.220, -13098658...
# 101  POLYGON ((-13073075.796 3919158.524, -13074423...
# 105  POLYGON ((-13585890.862 4467090.861, -13585887...
# 107  POLYGON ((-13573001.314 4750178.638, -13573044...

# %% [markdown]
# This for loop sets the geometry field in the ffjobs row equal to the geometry data we pulled from the counties dataframe. Now, we should have the right geometry data in ffjobs to help us visualize employment data per county.

# %% [markdown]
# ## Mapping the Data

# %% [markdown]
# First, let's visualize all fossil fuel employment in California. I want to use the counties dataset as the basemap, and I also want to ensure that counties with no fossil fuel employment don't stand out on the map.

# %%
# use subplots that make it easier to create multiple layered maps
fig, ax = plt.subplots(figsize=(15, 15))

# turn the axis off
ax.axis('off')

# set a title
ax.set_title('Summary Fossil Fuel Employment by County Map ',fontsize=16)

# add a basemap
counties.plot(alpha=0.5, color = 'white', edgecolor ='grey', ax=ax)

# plot employment values for ffjobs
ffjobs_trimmed2.plot(column = 'EMPLOYMENT',
            alpha=0.75, 
            legend = True, 
            linewidth = 1, 
            cmap = 'twilight', 
            edgecolor='grey',
            figsize=(12,10),
            ax=ax)

# %% [markdown]
# Great, the map above visualizes the employment count in each county. It sets all counties with no fossil fuel generation jobs to white. I also soften the county boundaries by setting them to grey. It would be better if we could normalize the data, but our data set did not include total employment counts per county.

# %% [markdown]
# Next, let's visualize some subsets of our data side by side. We use subplots to generate two plots next to each other.

# %%
# use subplots that make it easier to create multiple layered maps
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# turn the axis off
ax1.axis('off')
ax2.axis('off')

# set a title for ax1
ax1.set_title('Petroleum Refineries Employment by County Map ',fontsize=16)

# add a basemap
counties.plot(alpha=0.5, color = 'white', edgecolor ='grey', ax=ax1)

# define petroleum variable
petroleum = ffjobs_trimmed2[ffjobs_trimmed2.JOBTYPE_NAICS == 'Petroleum refineries']

# plot EMPlOYMENT values for petroleum refineries 
petroleum.plot(column = 'EMPLOYMENT',
            alpha=0.75, 
            legend = True, 
            linewidth = 1, 
            cmap = 'OrRd', 
            edgecolor='grey',
            figsize=(12,10), ax=ax1)


# set a title for ax2
ax2.set_title('Pipeline Transportation Employment by County Map ',fontsize=16)

# add a basemap
counties.plot(alpha=0.5, color = 'white', edgecolor ='grey', ax=ax2)

# define pipeline variable
pipeline = ffjobs_trimmed2[ffjobs_trimmed2.JOBTYPE_NAICS == 'Pipeline transportation']

# plot EMP values for pipeline transportation
pipeline.plot(column = 'EMPLOYMENT',
            alpha=0.75, 
            legend = True, 
            linewidth = 1, 
            cmap = 'OrRd', 
            edgecolor='grey',
            figsize=(12,10),
            ax=ax2)

# %% [markdown]
# Next, I want to visualize only the counties with over 500 fossil fuel jobs.

# %%
# use subplots that make it easier to create multiple layered maps
fig, ax = plt.subplots(figsize=(15, 15))

# turn the axis off
ax.axis('off')

# set a title
ax.set_title('Counties with Fossil Fuel Employment > 500 ',fontsize=16)

# add a basemap
counties.plot(alpha=0.5, color = 'white', edgecolor ='grey', ax=ax)

# define a new variable noN that is assigned to a new dataframe where none of the rows have the value of N within the EMP column. 
noN = ffjobs_trimmed2[ffjobs_trimmed2['EMPLOYMENT'] != 'N']

# plot all of the values where EMP is greater than 500 using the noN variable, which excludes all N values. 
noN[noN['EMPLOYMENT'].astype(int) > 500].plot(column = 'EMPLOYMENT',
            alpha=0.75, 
            legend = True, 
            linewidth = 1, 
            cmap = 'winter', 
            edgecolor='grey',
            figsize=(12,10),
            ax=ax)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %% [markdown]
# I produce a plot that visualizes all the counties with more than 500 fossil fuel jobs.
#
# To create the desired plot, I had to deal with two problems that stemmed from comparing EMP with an integer (500): 1) there were a few EMP rows with N values, which are none integer and 2) EMP data was originally string data type. So, on top of what I've done above, I must create a new variable assigned to a new dataframe to exclude all rows that have the value N within the EMP column. I also use the astype function to convert EMP values to integers.
#
# And last but not least, although the color scheme 'twilight' is the best, it was time to change things up so I used the 'winter' colormap.
